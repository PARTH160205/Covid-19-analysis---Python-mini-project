# %% [markdown]
# # COVID 19 DATASET ANALYSIS

# %%
import pandas as pd

# %%
data = pd.read_csv(
    r"E:\Data analytics learning\data analysis project\Covid 19 data analysis python\Covid19.csv"
)

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
data.count()
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # Number of confirmed,deaths and recovered cases in region

# %%
data.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
data.groupby('Region').sum()
# Out:
#                          Date State  Confirmed  Deaths  Recovered
# Region
# Afghanistan         4/29/2020     0       1939      60        252
# Albania             4/29/2020     0        766      30        455
# Algeria             4/29/2020     0       3848     444       1702
# Andorra             4/29/2020     0        743      42        423
# Angola              4/29/2020     0         27       2          7
# ...                       ...   ...        ...     ...        ...
# West Bank and Gaza  4/29/2020     0        344       2         71
# Western Sahara      4/29/2020     0          6       0          5
# Yemen               4/29/2020     0          6       0          1
# Zambia              4/29/2020     0         97       3         54
# Zimbabwe            4/29/2020     0         32       4          5
#
# [187 rows x 5 columns]

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False)  # descending order
# Out:
# Region
# US                  1039909
# Spain                236899
# Italy                203591
# France               166543
# UK                   166441
#                      ...
# Mauritania                8
# Papua New Guinea          8
# Bhutan                    7
# Yemen                     6
# Western Sahara            6
# Name: Confirmed, Length: 187, dtype: int64

# %% [markdown]
# # remove all records where confirmed cases is less than 10

# %%
data[data.Confirmed<10]
# Out:
#           Date                             State                 Region  \
# 18   4/29/2020                               NaN                 Bhutan
# 98   4/29/2020                               NaN             MS Zaandam
# 105  4/29/2020                               NaN             Mauritania
# 126  4/29/2020                               NaN       Papua New Guinea
# 140  4/29/2020                               NaN  Sao Tome and Principe
# 177  4/29/2020                               NaN         Western Sahara
# 178  4/29/2020                               NaN                  Yemen
# 184  4/29/2020                          Anguilla                     UK
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba            Netherlands
# 194  4/29/2020            British Virgin Islands                     UK
# 203  4/29/2020      Diamond Princess cruise ship                 Canada
# 272  4/29/2020             Northwest Territories                 Canada
# ...

# %%
data =data[~(data.Confirmed<10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %% [markdown]
# # region in which max number of confirmed cases recorded

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(1)
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %% [markdown]
# # region in which min number of confirmed cases recorded

# %%
data.groupby('Region')['Confirmed'].sum().sort_values(ascending =True).head(1)
# Out:
# Region
# Yemen    6
# Name: Confirmed, dtype: int64

# %% [markdown]
# # region in which min number of deaths cases recorded

# %%
data.groupby('Region')['Deaths'].sum().sort_values(ascending =True).head(1)
# Out:
# Region
# Cambodia    0
# Name: Deaths, dtype: int64

# %% [markdown]
# # Number of confirmed,deaths and recovered cases were reported from india till 29 april 2020

# %%
data = data[data.Region == 'India']

# %%
data
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# # Sort data with number of confirmed cases in asc order

# %%
data.sort_values(by = 'Confirmed' , ascending = True).head(50)
# Out:
#           Date                             State  \
# 284  4/29/2020                         Recovered
# 285  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 289  4/29/2020         Saint Pierre and Miquelon
# 305  4/29/2020                             Tibet
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...

# %% [markdown]
# # Sort data with number of Recovered  cases in desc order

# %%
data.sort_values(by = 'Recovered' , ascending = False).head(50)
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...

# %% [markdown]
# # Replace all empty values in state column with "No data"

# %%
data = data.fillna("No data")

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020   No data     Afghanistan       1939      60        252
# 1    4/29/2020   No data         Albania        766      30        455
# 2    4/29/2020   No data         Algeria       3848     444       1702
# 3    4/29/2020   No data         Andorra        743      42        423
# 4    4/29/2020   No data          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]
